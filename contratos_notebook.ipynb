# %% [markdown]
# # Spark notebook
#
# This notebook makes a request to Portal da Transparência and gets the data that will be loaded to Cassandra.

# %% [markdown]
# ## Make the request to the API
#
# This section makes the request to Portal da Transparência. Provided you have the unique key to make the requests to the API, it then makes the request to the "contratos" get request, using the variables "organization_code" (código do órgão (SIAFI)), "initial_date", and "number_of_pages" that you want to request. For this case, I requested 500 pages.
#
# It will then write into a GCS bucket for further processing.

# %%
import requests
import json
from google.cloud import storage

def get_api_data(organization_code, initial_date, number_of_pages):
    url = "https://api.portaldatransparencia.gov.br/api-de-dados/contratos"
    key = "34ed1e6231d354e35948e24139e48ee9"

    params = {"codigoOrgao": organization_code, "quantidade": 100, "dataInicial": initial_date, "page": 1}
    headers = {"accept": "*/*", "chave-api-dados": key}

    all_data = []  # Create a single list to store all data

    while params["page"] <= number_of_pages:
        try:
            response = requests.get(url, params=params, headers=headers)
            response.raise_for_status()
            json_data = response.json()

            if not json_data:
                break

            all_data.extend(json_data)  # Append data to the single list
            params["page"] += 1

        except requests.exceptions.RequestException as e:
            print("Error making the request:", e)
            break

    return all_data

def save_in_json(data, file_name):
    with open(file_name, "w", encoding="utf-8") as json_file:
        json.dump(data, json_file, ensure_ascii=False, indent=2)

organization_code = "52111"  # Replace with your organization code
initial_date = "01/01/2018"  # Replace with your start date
number_of_pages = 500  # Replace with the desired number of pages
json_file_name = "output_data.json"  # Replace with your desired output file name

page_data = get_api_data(organization_code, initial_date, number_of_pages)
save_in_json(page_data, json_file_name)

# %%
def get_api_data(organization_code, initial_date, number_of_pages):
    url = "https://api.portaldatransparencia.gov.br/api-de-dados/contratos"
    key = "34ed1e6231d354e35948e24139e48ee9"

    params = {"codigoOrgao": organization_code, "quantidade": 100, "dataInicial": initial_date, "page": 1}
    headers = {"accept": "*/*", "chave-api-dados": key}

    all_data = []  # Create a single list to store all data

    while params["page"] <= number_of_pages:
        try:
            response = requests.get(url, params=params, headers=headers)
            response.raise_for_status()
            json_data = response.json()

            if not json_data:
                break

            all_data.extend(json_data)  # Append data to the single list
            params["page"] += 1

        except requests.exceptions.RequestException as e:
            print("Error making the request:", e)
            break

    return all_data

# %%
def save_in_gcs(data, bucket_name, file_name):
    client = storage.Client()
    bucket = client.bucket(bucket_name)

    blob = bucket.blob(file_name)
    blob.upload_from_string(json.dumps(data, ensure_ascii=False, indent=2), content_type='application/json')

# %%
def main():
    organization_code = "52111"
    initial_date = "01/01/2018"
    number_of_pages = 500
    bucket_name = "cassandra-project-leorickli"
    file_name = "raw/contratos_raw.json"

    page_data = get_api_data(organization_code, initial_date, number_of_pages)
    save_in_gcs(page_data, bucket_name, file_name)

if __name__ == "__main__":
    main()

# %% [markdown]
# ## Clean, transform and convert the json file into csv
#
# This section prepares the json file by cleaning it, transforming into csv and sending it into a "curated" bucket, so Cassandra can read it in the proper way.

# %%
from typing import Final, Dict, Tuple
from pyspark.sql.session import SparkSession
from pyspark.sql import DataFrame as SDF
from pyspark.sql.functions import *
from pyspark.sql.types import StructType, ArrayType
from pyspark.sql import SparkSession
from pyspark.sql.functions import explode_outer, col, when, regexp_replace

# %%
def flatten_json(df_arg, parent_name=""):
    df = df_arg
    stack = [(df, "")]

    while stack:
        current_df, parent_name = stack.pop()

        for field in current_df.schema.fields:
            data_type = str(field.dataType)
            column_name = field.name
            full_column_name = f"{parent_name}_{column_name}" if parent_name else column_name

            if data_type.startswith('ArrayType'):
                current_df = current_df.withColumn(full_column_name, explode_outer(col(column_name)))

            elif data_type.startswith('StructType'):
                struct_fields = [f"{column_name}.{subfield.name} AS {full_column_name}_{subfield.name}" for subfield in field.dataType.fields]
                current_df = current_df.selectExpr("*", *struct_fields).drop(column_name)

        stack.extend([(current_df, full_column_name) for field in current_df.schema.fields if str(field.dataType).startswith('StructType')])

    # Rename specific columns
    current_df = current_df.withColumnRenamed("valorInicialCompra_unidadeGestoraCompras_orgaoVinculado_codigoSIAFI", "unidadeGestoraCompras_orgaoVinculado_codigoSIAFI")
    current_df = current_df.withColumnRenamed("valorInicialCompra_unidadeGestoraCompras_orgaoVinculado_cnpj", "unidadeGestoraCompras_orgaoVinculado_cnpj")
    current_df = current_df.withColumnRenamed("valorInicialCompra_unidadeGestoraCompras_orgaoVinculado_sigla", "unidadeGestoraCompras_orgaoVinculado_sigla")
    current_df = current_df.withColumnRenamed("valorInicialCompra_unidadeGestoraCompras_orgaoVinculado_nome", "unidadeGestoraCompras_orgaoVinculado_nome")    
    current_df = current_df.withColumnRenamed("valorInicialCompra_unidadeGestoraCompras_orgaoMaximo_codigo", "unidadeGestoraCompras_orgaoMaximo_codigo")    
    current_df = current_df.withColumnRenamed("valorInicialCompra_unidadeGestoraCompras_orgaoMaximo_sigla", "unidadeGestoraCompras_orgaoMaximo_sigla")    
    current_df = current_df.withColumnRenamed("valorInicialCompra_unidadeGestoraCompras_orgaoMaximo_nome", "unidadeGestoraCompras_orgaoMaximo_nome")
    current_df = current_df.withColumnRenamed("valorInicialCompra_unidadeGestora_orgaoVinculado_codigoSIAFI", "unidadeGestora_orgaoVinculado_codigoSIAFI")  
    current_df = current_df.withColumnRenamed("valorInicialCompra_unidadeGestora_orgaoVinculado_cnpj", "unidadeGestora_orgaoVinculado_cnpj")  
    current_df = current_df.withColumnRenamed("valorInicialCompra_unidadeGestora_orgaoVinculado_sigla", "unidadeGestora_orgaoVinculado_sigla")  
    current_df = current_df.withColumnRenamed("valorInicialCompra_unidadeGestora_orgaoVinculado_nome", "unidadeGestora_orgaoVinculado_nome")  
    current_df = current_df.withColumnRenamed("valorInicialCompra_unidadeGestora_orgaoMaximo_codigo", "unidadeGestora_orgaoMaximo_codigo")  
    current_df = current_df.withColumnRenamed("valorInicialCompra_unidadeGestora_orgaoMaximo_sigla", "unidadeGestora_orgaoMaximo_sigla")  
    current_df = current_df.withColumnRenamed("valorInicialCompra_unidadeGestora_orgaoMaximo_nome", "unidadeGestora_orgaoMaximo_nome") 

    # Handle empty strings
    for field in current_df.schema.fields:
        data_type = str(field.dataType)
        column_name = field.name

        if 'StringType' in data_type:
            current_df = current_df.withColumn(column_name, when(col(column_name) == '""', None).otherwise(col(column_name)))

    # Remove or replace \r\n in text columns
    for field in current_df.schema.fields:
        data_type = str(field.dataType)
        column_name = field.name

        if 'StringType' in data_type:
            current_df = current_df.withColumn(column_name, regexp_replace(col(column_name), r'\r\n', ' '))
            current_df = current_df.withColumn(column_name, regexp_replace(col(column_name), r'\"', ''))


    return current_df

# %%
if __name__ == "__main__":
    # Create a Spark session
    spark = SparkSession.builder.appName("FlatJson").config("spark.driver.memory", "4g").master("local[*]").getOrCreate()

    # Your GCS bucket and JSON file path
    gcs_bucket = "cassandra-project-leorickli"
    json_file_path = f"gs://{gcs_bucket}/raw/contratos_raw.json"

    # Read the JSON file into a DataFrame with UTF-8 encoding
    df = spark.read.option("multiline", "true").option("encoding", "UTF-8").json(json_file_path)

    # Flatten the DataFrame with nested fields named using the parent object's name as a prefix
    flattened_df = flatten_json(df)

    # Define the output CSV file path in GCS
    gcs_output_path = f"gs://{gcs_bucket}/curated/contratos_curated"

    # Write the CSV file to GCS with UTF-8 encoding
    flattened_df.coalesce(1).write.option("encoding", "UTF-8").csv(gcs_output_path, header=True, mode='overwrite')

    # Show the flattened DataFrame
    flattened_df.show(20, False)
# Out:
# 23/12/24 12:06:54 WARN SparkSession: Using an existing Spark session; only runtime SQL configurations will take effect.
# 23/12/24 12:07:09 WARN package: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# [Stage 2:>                                                          (0 + 1) / 1]
# +--------------+---------------+------------------+-----------------+-----------------------------------------------------------------------------------------------------------------------------+---------+----------------------------+---------+--------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------+----------------+------------------+------------------------------------+-------------+---------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------+-----------------------+-------------+---------------------------------------------------------------------------+-------------------------------------------------+--------------------------------+---------------------------------------------------------------------------+-------------------------------+---------------------+-----------------------------+---------------------------------------------+----------------------------+------------------------------------+------------------------------------------+---------------------------------+-------------------------------+--------------------------------+----------------------------------+-----------------------------------------+----------------------------------+-----------------------------------+----------------------------------------+--------------------------------------+---------------------------------------+-----------------------------------------+------------------------------------------------+-----------------------------------------+------------------------------------------+
# |dataAssinatura|dataFimVigencia|dataInicioVigencia|dataPublicacaoDOU|fundamentoLegal                                                                                                              |id       |modalidadeCompra            |numero   |numeroProcesso|objeto                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     |situacaoContrato       |valorFinalCompra|valorInicialCompra|compra_contatoResponsavel           |compra_numero|compra_numeroProcesso|compra_objeto                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               |fornecedor_cnpjFormatado|fornecedor_cpfFormatado|fornecedor_id|fornecedor_nome                                                            |fornecedor_nomeFantasiaReceita                   |fornecedor_numeroInscricaoSocial|fornecedor_razaoSocialReceita                                              |fornecedor_tipo                |unidadeGestora_codigo|unidadeGestora_descricaoPoder|unidadeGestora_nome                          |unidadeGestoraCompras_codigo|unidadeGestoraCompras_descricaoPoder|unidadeGestoraCompras_nome                |unidadeGestora_orgaoMaximo_codigo|unidadeGestora_orgaoMaximo_nome|unidadeGestora_orgaoMaximo_sigla|unidadeGestora_orgaoVinculado_cnpj|unidadeGestora_orgaoVinculado_codigoSIAFI|unidadeGestora_orgaoVinculado_nome|unidadeGestora_orgaoVinculado_sigla|unidadeGestoraCompras_orgaoMaximo_codigo|unidadeGestoraCompras_orgaoMaximo_nome|unidadeGestoraCompras_orgaoMaximo_sigla|unidadeGestoraCompras_orgaoVinculado_cnpj|unidadeGestoraCompras_orgaoVinculado_codigoSIAFI|unidadeGestoraCompras_orgaoVinculado_nome|unidadeGestoraCompras_orgaoVinculado_sigla|
# +--------------+---------------+------------------+-----------------+-----------------------------------------------------------------------------------------------------------------------------+---------+----------------------------+---------+--------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------+----------------+------------------+------------------------------------+-------------+---------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------+-----------------------+-------------+---------------------------------------------------------------------------+-------------------------------------------------+--------------------------------+---------------------------------------------------------------------------+-------------------------------+---------------------+-----------------------------+---------------------------------------------+----------------------------+------------------------------------+------------------------------------------+---------------------------------+-------------------------------+--------------------------------+----------------------------------+-----------------------------------------+----------------------------------+-----------------------------------+----------------------------------------+--------------------------------------+---------------------------------------+-----------------------------------------+------------------------------------------------+-----------------------------------------+------------------------------------------+
# |2018-04-02    |2023-04-02     |2018-04-02        |2018-07-06       |Fundamento Legal: LEI N° 8.666/93                                                                                            |118035917|Pregão                      |000812017|Sem informação|Objeto: CONTRATAÇÃO DE SERVIÇOS DE MANUTENÇÃO CORRETIVA, PREVENTIVA E ADEQUAÇÕES DE SISTEMAS ELETRÔNICOS DE SEGURANÇA                                                                                                                                                                                                                                                                                                                                                                      |Não se aplica          |134225.0        |134225.0          |WAGNER SOARES MATHEUS               |000512017    |67564010214201736    |Objeto: Pregão Eletrônico -  Contratação de empresa especializada para prestação de serviços de assistência técnica de manutenção preventiva, corretiva e adequação de instalações com o fornecimento de peças e componentes para parque de equipamentos de segurança eletrônica instalados na Guarnição da Aeronáutica dos Afonsos.                                                                                                                                                                        |05.925.793/0001-73      |                       |18142881     |ZOIT CONSULTORIA E SERVICOS DE TECNOLOGIA DA INFORMACAO LTDA               |                                                 |                                |ZOIT CONSULTORIA E SERVICOS DE TECNOLOGIA DA INFORMACAO LTDA               |Entidades Empresariais Privadas|120623               |EXECUTIVO                    |GRUPAMENTO DE APOIO DOS AFONSOS              |120623                      |EXECUTIVO                           |GRUPAMENTO DE APOIO DOS AFONSOS           |52000                            |Ministério da Defesa           |DEFESA                          |00394429000100                    |52111                                    |Comando da Aeronáutica            |CMDO AERONÁUTICA                   |20101                                   |Sem informação                        |                                       |                                         |52111                                           |COMANDO DA AERONAUTICA                   |                                          |
# |2018-05-18    |2022-01-01     |2018-05-18        |2018-12-21       |Fundamento Legal: LEI 8666/93                                                                                                |118039309|Inexigibilidade de Licitação|000082018|Sem informação|Objeto: PRESTAÇÃO DE SERVIÇOS DE ASSISTENCIA MEDICA HOSPITALAR.                                                                                                                                                                                                                                                                                                                                                                                                                            |Não se aplica          |150000.0        |150000.0          |JULIO CESAR DA GAMA APOLINARIO      |000032018    |67530000984201849    |Objeto: Prestação de serviço médico-hospitalar complementar de saúde.                                                                                                                                                                                                                                                                                                                                                                                                                                       |86.383.973/0001-72      |                       |19240971     |COOPERATIVA DE TRABALHO MEDICO E ATIVIDADES AFINS DE BELO HORIZONTE-BELCOOP|BELCOOP -BH                                      |                                |COOPERATIVA DE TRABALHO MEDICO E ATIVIDADES AFINS DE BELO HORIZONTE-BELCOOP|Entidades Empresariais Privadas|120636               |EXECUTIVO                    |GRUPAMENTO DE APOIO DE LAGOA SANTA           |120636                      |EXECUTIVO                           |GRUPAMENTO DE APOIO DE LAGOA SANTA        |52000                            |Ministério da Defesa           |DEFESA                          |00394429000100                    |52111                                    |Comando da Aeronáutica            |CMDO AERONÁUTICA                   |20101                                   |Sem informação                        |                                       |                                         |52111                                           |COMANDO DA AERONAUTICA                   |                                          |
# |2018-05-28    |2018-11-19     |2018-05-28        |2018-05-30       |Fundamento Legal: Lei n¿ 8.666/93, Decreto n¿ 2.271/97.                                                                      |118039565|Inexigibilidade de Licitação|102018   |Sem informação|Objeto: Serviços técnicos especializados de treinamento e aquisição de licenças do software FME, incluindo o fornecimento de 2 (duas) licenças fixas desktop da ferramenta FME, documentação técnica da instalação/configuração e manual degarantia técnica.                                                                                                                                                                                                                               |Publicado              |51538.32        |51538.32          |EDMILSON JOSE COSTA                 |000122018    |67600019013201711    |Objeto: Aquisição de serviços técnicos especializados de treinamento e aquisição de licenças do software FME, conforme as especificações e as condições detalhadas no Projeto Básico nº 265.06.I00.PB.007.00.                                                                                                                                                                                                                                                                                               |09.277.679/0001-35      |                       |23843727     |INOVACAO TECNOLOGIA DA INFORMACAO GEOGRAFICA LTDA                          |INOVACAO TECNOLOGIA DA INFORMACAO GEOGRAFICA LTDA|                                |INOVACAO TECNOLOGIA DA INFORMACAO GEOGRAFICA LTDA                          |Entidades Empresariais Privadas|120646               |EXECUTIVO                    |GRUPAMENTO DE APOIO AS UNIDADES DO SISTEMA DE|120646                      |EXECUTIVO                           |GRUPAMENTO DE APOIO ÀS UND DO SIST DO CEA |52000                            |Ministério da Defesa           |DEFESA                          |00394429000100                    |52111                                    |Comando da Aeronáutica            |CMDO AERONÁUTICA                   |20101                                   |Sem informação                        |                                       |                                         |52111                                           |COMANDO DA AERONAUTICA                   |                                          |
# |2018-06-01    |2048-06-01     |2018-06-01        |2021-03-24       |                                                                                                                             |118039949|Dispensa de Licitação       |000052018|Sem informação|Objeto: SERVIÇO PÚBLICO - ENERGISA                                                                                                                                                                                                                                                                                                                                                                                                                                                         |Não se aplica          |14000.0         |14000.0           |PAULO EDUARDO ALBUQUERQUE DE MAGELLA|000052015    |43/CINDACTA3/2015    |Objeto: Fornecimento de energia DTCEA-AR                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |09.095.183/0001-40      |                       |3420221      |ENERGISA PARAIBA - DISTRIBUIDORA DE ENERGIA S.A                            |ENERGISA                                         |                                |ENERGISA PARAIBA - DISTRIBUIDORA DE ENERGIA S.A                            |Entidades Empresariais Privadas|120632               |EXECUTIVO                    |GRUPAMENTO DE APOIO DE RECIFE                |120632                      |EXECUTIVO                           |GRUPAMENTO DE APOIO DE RECIFE             |52000                            |Ministério da Defesa           |DEFESA                          |00394429000100                    |52111                                    |Comando da Aeronáutica            |CMDO AERONÁUTICA                   |20101                                   |Sem informação                        |                                       |                                         |52111                                           |COMANDO DA AERONAUTICA                   |                                          |
# |2018-06-11    |2019-06-10     |2018-06-11        |2018-06-20       |Fundamento Legal: Lei nº 8.666, de 21 de junho de 1993, na Lei nº 10.520, de 17 de julho de 2002, na Lei Complementar nº 123.|118040333|Inexigibilidade de Licitação|52018    |Sem informação|Objeto: Prestação de serviços especializados em Radiocirurgia (RTC) - nível 1, lesão única e/ou um isocentro - por tratamento, Radiocirurgia (RTC) - nível 2, duas lesões e/ou dois a quatro isocentros - por tratamento, Radiocirurgia (RTC) - nível 3, três lesões e/ou de mais de quatro isocentros - por tratamento, Radioterapia com Modulação da Intensidade do Feixe (IMRT) - portratamento, Radioterapia Conformada Tridimensional (RCT-3D) com Acelerador Linear - por tratamento.|Publicado              |164417.08       |100000.0          |MARCO HAROLDO AKIO ODAM             |000092018    |67619006973201711    |Objeto: Credenciamento de serviços Médicos-Hospitalares - ONCOVILLE ATENDIMENTO ONCOLÓGICO INTEGRAL LTDA.                                                                                                                                                                                                                                                                                                                                                                                                   |04.707.180/0001-05      |                       |14142724     |ONCOVILLE ATENDIMENTO ONCOLOGICO INTEGRAL LTDA                             |                                                 |                                |ONCOVILLE ATENDIMENTO ONCOLOGICO INTEGRAL LTDA                             |Entidades Empresariais Privadas|120644               |EXECUTIVO                    |GRUPAMENTO DE APOIO DE CURITIBA              |120644                      |EXECUTIVO                           |GRUPAMENTO DE APOIO DE CURITIBA           |52000                            |Ministério da Defesa           |DEFESA                          |00394429000100                    |52111                                    |Comando da Aeronáutica            |CMDO AERONÁUTICA                   |20101                                   |Sem informação                        |                                       |                                         |52111                                           |COMANDO DA AERONAUTICA                   |                                          |
# |2018-08-01    |2019-05-03     |2018-08-01        |2018-12-18       |Fundamento Legal: Lei 8.666/93                                                                                               |118043085|Inexigibilidade de Licitação|82018    |Sem informação|Objeto: Prestação de serviços de assistência médico-hospitalar aos usuários do Fundo de Saúde da Aeronáutica (FUNSA), nos termos definidos pela legislação aplicável.                                                                                                                                                                                                                                                                                                                      |Publicado              |927773.16       |900000.0          |SIDNEY DIONISIO TOLEDO              |004122018    |67267002522201823    |Objeto: Credenciamento no Estado de São Paulo, de pessoas físicas e jurídicas  interessadas  na  prestação  de  serviços  de  assistência  médico-hospitalar,  fonoaudiologia,  fisioterapia,  nutrição,  psicologia,  terapia ocupacional   e   laboratorial,   bem   como   serviços   de   assistência domiciliar  (home  care)  aos  beneficiários  do  Sistema  de  Saúde  da Aeronáutica  (SISAU)  e,  eventualmente,  aos  beneficiários  do  Sistema de   Saúde   de   outras   Forças   Singulares.|62.106.505/0001-92      |                       |6120356      |CRUZ AZUL DE SAO PAULO                                                     |HOSPITAL E MATERNIDADE SANTA MARIA               |                                |CRUZ AZUL DE SAO PAULO                                                     |Entidades Sem Fins Lucrativos  |120633               |EXECUTIVO                    |GRUPAMENTO DE APOIO DE SAO PAULO             |120633                      |EXECUTIVO                           |GRUPAMENTO DE APOIO DE SÃO PAULO          |52000                            |Ministério da Defesa           |DEFESA                          |00394429000100                    |52111                                    |Comando da Aeronáutica            |CMDO AERONÁUTICA                   |20101                                   |Sem informação                        |                                       |                                         |52111                                           |COMANDO DA AERONAUTICA                   |                                          |
# |2018-10-29    |2019-05-03     |2018-10-29        |2018-12-18       |Fundamento Legal: Lei 8.666/93                                                                                               |118051469|Inexigibilidade de Licitação|472018   |Sem informação|Objeto: Prestação de serviços de assistência médico-hospitalar em Oncologia (quimioterapia, imunoterapia e hormonioterapia) aos pacientes adultos (acima de 18 anos de idade), aos usuários do Fundo de Saúde da Aeronáutica (FUNSA), nos termos definidos pela legislação aplicável.                                                                                                                                                                                                      |Publicado              |900000.0        |900000.0          |SIDNEY DIONISIO TOLEDO              |004122018    |67267002522201823    |Objeto: Credenciamento no Estado de São Paulo, de pessoas físicas e jurídicas  interessadas  na  prestação  de  serviços  de  assistência  médico-hospitalar,  fonoaudiologia,  fisioterapia,  nutrição,  psicologia,  terapia ocupacional   e   laboratorial,   bem   como   serviços   de   assistência domiciliar  (home  care)  aos  beneficiários  do  Sistema  de  Saúde  da Aeronáutica  (SISAU)  e,  eventualmente,  aos  beneficiários  do  Sistema de   Saúde   de   outras   Forças   Singulares.|03.988.640/0001-40      |                       |17042913     |ONCOTERAPIA S/S LTDA                                                       |                                                 |                                |ONCOTERAPIA S/S LTDA                                                       |Entidades Empresariais Privadas|120633               |EXECUTIVO                    |GRUPAMENTO DE APOIO DE SAO PAULO             |120633                      |EXECUTIVO                           |GRUPAMENTO DE APOIO DE SÃO PAULO          |52000                            |Ministério da Defesa           |DEFESA                          |00394429000100                    |52111                                    |Comando da Aeronáutica            |CMDO AERONÁUTICA                   |20101                                   |Sem informação                        |                                       |                                         |52111                                           |COMANDO DA AERONAUTICA                   |                                          |
# |2018-10-10    |2019-09-09     |2018-10-29        |2018-11-20       |Fundamento Legal: Lei nº 8.666/1993                                                                                          |118051533|Concorrência                |1032018  |Sem informação|Objeto: Reforma do prédio do APP-SP do DTCEA-SP                                                                                                                                                                                                                                                                                                                                                                                                                                            |Retificação - Publicado|2322069.86      |1890969.69        |                                    |000042018    |67600003997201807    |Objeto: Reforma no prédio do Controle de Aproximação de São Paulo (APP-SP), do Destacamento de Controle do Espaço Aéreo de São Paulo (DTCEA-SP), mediante o regime de empreitada por preço global, conforme especificações constantes no Projeto Básico - ANEXO I ao Edital.                                                                                                                                                                                                                                |00.242.092/0001-16      |                       |18544653     |MULTICON ENGENHARIA LTDA                                                   |                                                 |                                |MULTICON ENGENHARIA LTDA                                                   |Entidades Empresariais Privadas|120195               |EXECUTIVO                    |CENTRO DE AQUISICOES ESPECIFICAS             |120195                      |EXECUTIVO                           |CENTRO DE AQUISIÇÕES ESPECIFICAS          |52000                            |Ministério da Defesa           |DEFESA                          |00394429000100                    |52111                                    |Comando da Aeronáutica            |CMDO AERONÁUTICA                   |20101                                   |Sem informação                        |                                       |                                         |52111                                           |COMANDO DA AERONAUTICA                   |                                          |
# |2018-11-12    |2019-05-03     |2018-11-12        |2018-12-18       |Fundamento Legal: Lei 8.666/93                                                                                               |118053325|Inexigibilidade de Licitação|492018   |Sem informação|Objeto: Prestação de serviços de assistência médico-hospitalar para realização de exames anatomopáticos aos usuários do Fundo de Saúde da Aeronáutica (FUNSA), nos termos definidos pela legislação aplicável.                                                                                                                                                                                                                                                                             |Publicado              |301544.1        |300000.0          |SIDNEY DIONISIO TOLEDO              |004122018    |67267002522201823    |Objeto: Credenciamento no Estado de São Paulo, de pessoas físicas e jurídicas  interessadas  na  prestação  de  serviços  de  assistência  médico-hospitalar,  fonoaudiologia,  fisioterapia,  nutrição,  psicologia,  terapia ocupacional   e   laboratorial,   bem   como   serviços   de   assistência domiciliar  (home  care)  aos  beneficiários  do  Sistema  de  Saúde  da Aeronáutica  (SISAU)  e,  eventualmente,  aos  beneficiários  do  Sistema de   Saúde   de   outras   Forças   Singulares.|43.225.408/0001-74      |                       |28242517     |PLINIO SANTOS ANATOMIA PATOLOGICA LTDA                                     |LABORATORIO PLINIO SANTOS                        |                                |PLINIO SANTOS ANATOMIA PATOLOGICA LTDA                                     |Entidades Empresariais Privadas|120633               |EXECUTIVO                    |GRUPAMENTO DE APOIO DE SAO PAULO             |120633                      |EXECUTIVO                           |GRUPAMENTO DE APOIO DE SÃO PAULO          |52000                            |Ministério da Defesa           |DEFESA                          |00394429000100                    |52111                                    |Comando da Aeronáutica            |CMDO AERONÁUTICA                   |20101                                   |Sem informação                        |                                       |                                         |52111                                           |COMANDO DA AERONAUTICA                   |                                          |
# |2018-11-13    |2019-05-03     |2018-11-13        |2018-12-18       |Fundamento Legal: Lei 8.666/93                                                                                               |118054861|Inexigibilidade de Licitação|502018   |Sem informação|Objeto: Prestação de serviços de assistência médico-hospitalar na área de nefrologia aos usuários do Fundo de Saúde da Aeronáutica (FUNSA), nos termos definidos pela legislação aplicável.                                                                                                                                                                                                                                                                                                |Publicado              |200000.0        |200000.0          |SIDNEY DIONISIO TOLEDO              |004122018    |67267002522201823    |Objeto: Credenciamento no Estado de São Paulo, de pessoas físicas e jurídicas  interessadas  na  prestação  de  serviços  de  assistência  médico-hospitalar,  fonoaudiologia,  fisioterapia,  nutrição,  psicologia,  terapia ocupacional   e   laboratorial,   bem   como   serviços   de   assistência domiciliar  (home  care)  aos  beneficiários  do  Sistema  de  Saúde  da Aeronáutica  (SISAU)  e,  eventualmente,  aos  beneficiários  do  Sistema de   Saúde   de   outras   Forças   Singulares.|45.181.930/0001-27      |                       |14145198     |ENESP EQUIPE NEFROLOGICA DE SAO PAULO LTDA                                 |                                                 |                                |ENESP EQUIPE NEFROLOGICA DE SAO PAULO LTDA                                 |Entidades Empresariais Privadas|120633               |EXECUTIVO                    |GRUPAMENTO DE APOIO DE SAO PAULO             |120633                      |EXECUTIVO                           |GRUPAMENTO DE APOIO DE SÃO PAULO          |52000                            |Ministério da Defesa           |DEFESA                          |00394429000100                    |52111                                    |Comando da Aeronáutica            |CMDO AERONÁUTICA                   |20101                                   |Sem informação                        |                                       |                                         |52111                                           |COMANDO DA AERONAUTICA                   |                                          |
# |2018-11-22    |2019-11-21     |2018-11-22        |2019-06-06       |Fundamento Legal: Lei 8.666, Artigo 57, inciso 2º, de 21 de junho de 1993.                                                   |118055437|Inexigibilidade de Licitação|772018   |Sem informação|Objeto: O objeto deste Termo de Credenciamento é a prestação de serviços especializados aos usuários do Fundo de Saúde da Aeronáutica(FUNSA).                                                                                                                                                                                                                                                                                                                                              |Publicado              |60000.0         |60000.0           |DANIEL FREITAS DE LIMA              |000832018    |67619004155201865    |Objeto: Credenciamento de serviços Médico-Hospitalares   HOSPITAL DO CORAÇÃO LTDA.                                                                                                                                                                                                                                                                                                                                                                                                                          |76.024.066/0001-83      |                       |19039866     |HOSPITAL DO CORACAO LTDA                                                   |                                                 |                                |HOSPITAL DO CORACAO LTDA                                                   |Entidades Empresariais Privadas|120644               |EXECUTIVO                    |GRUPAMENTO DE APOIO DE CURITIBA              |120644                      |EXECUTIVO                           |GRUPAMENTO DE APOIO DE CURITIBA           |52000                            |Ministério da Defesa           |DEFESA                          |00394429000100                    |52111                                    |Comando da Aeronáutica            |CMDO AERONÁUTICA                   |20101                                   |Sem informação                        |                                       |                                         |52111                                           |COMANDO DA AERONAUTICA                   |                                          |
# |2018-12-06    |2023-12-06     |2018-12-06        |2018-12-20       |Fundamento Legal: LEI 8666/93                                                                                                |118056973|Inexigibilidade de Licitação|000342018|Sem informação|Objeto: SERVIÇO DE ASSISTÊNCIA MÉDICO HOSPITALAR EM ANESTESIOLOGIA AOS USUÁRIOS DO FUNSA.                                                                                                                                                                                                                                                                                                                                                                                                  |Não se aplica          |100000.0        |20000.0           |LAERTE LOBATO DE MORAES             |060342017    |67215007837201872    |Objeto: Serviço de assistência médico hospitalar em anestesiologia aos usuários do FUNSA.                                                                                                                                                                                                                                                                                                                                                                                                                   |15.290.125/0001-70      |                       |27143220     |COOPERATIVA DOS MEDICOS ANESTESIOLOGISTAS NO E PARA                        |COOPANEST                                        |                                |COOPERATIVA DOS MEDICOS ANESTESIOLOGISTAS NO E PARA                        |Entidades Empresariais Privadas|120628               |EXECUTIVO                    |GRUPAMENTO DE APOIO DE BELEM                 |120628                      |EXECUTIVO                           |GRUPAMENTO DE APOIO DE BELÉM              |52000                            |Ministério da Defesa           |DEFESA                          |00394429000100                    |52111                                    |Comando da Aeronáutica            |CMDO AERONÁUTICA                   |20101                                   |Sem informação                        |                                       |                                         |52111                                           |COMANDO DA AERONAUTICA                   |                                          |
# |2018-12-10    |2019-12-10     |2018-12-10        |2019-01-08       |Fundamento Legal: Lei 8666/93                                                                                                |118057805|Inexigibilidade de Licitação|2322018  |Sem informação|Objeto: Serviço de assistência médica ambulatorial e SADT em endocrinologia e fisioterapia aos usuários do FUNSA.                                                                                                                                                                                                                                                                                                                                                                          |Publicado              |250000.0        |250000.0          |HELDER DE OLIVEIRA ANDRADA          |062322018    |67215018244201831    |Objeto: Serviço de assistência médica ambulatorial e SADT em endocrinologia e fisioterapia aos usuários do FUNSA.                                                                                                                                                                                                                                                                                                                                                                                           |08.265.478/0001-55      |                       |64301534     |CLINICA DE IMAGENOLOGIA AUXILIO DIAGNOSTICO LTDA                           |REABILITA                                        |                                |CLINICA DE IMAGENOLOGIA AUXILIO DIAGNOSTICO LTDA                           |Entidades Empresariais Privadas|120628               |EXECUTIVO                    |GRUPAMENTO DE APOIO DE BELEM                 |120628                      |EXECUTIVO                           |GRUPAMENTO DE APOIO DE BELÉM              |52000                            |Ministério da Defesa           |DEFESA                          |00394429000100                    |52111                                    |Comando da Aeronáutica            |CMDO AERONÁUTICA                   |20101                                   |Sem informação                        |                                       |                                         |52111                                           |COMANDO DA AERONAUTICA                   |                                          |
# |2018-12-10    |2023-12-10     |2018-12-10        |2021-03-17       |                                                                                                                             |118057997|Inexigibilidade de Licitação|002322018|Sem informação|Objeto: SERVIÇO DE ASSISTÊNCIA MÉDICA AMBULATORIAL E SADT EM ENDOCRINOLOGIA E FISIOTERAPIA AOS USUÁRIOS DO FUNSA                                                                                                                                                                                                                                                                                                                                                                           |Não se aplica          |80000.0         |80000.0           |HELDER DE OLIVEIRA ANDRADA          |062322018    |67215018244201831    |Objeto: Serviço de assistência médica ambulatorial e SADT em endocrinologia e fisioterapia aos usuários do FUNSA.                                                                                                                                                                                                                                                                                                                                                                                           |08.265.478/0001-55      |                       |64301534     |CLINICA DE IMAGENOLOGIA AUXILIO DIAGNOSTICO LTDA                           |REABILITA                                        |                                |CLINICA DE IMAGENOLOGIA AUXILIO DIAGNOSTICO LTDA                           |Entidades Empresariais Privadas|120013               |EXECUTIVO                    |CENTRO DE LANCAMENTO DE ALCANTARA            |120013                      |EXECUTIVO                           |MAER-GR.IMP.CENT.DE LANCAM.DE ALCANTARA/MA|52000                            |Ministério da Defesa           |DEFESA                          |00394429000100                    |52111                                    |Comando da Aeronáutica            |CMDO AERONÁUTICA                   |20101                                   |Sem informação                        |                                       |                                         |52111                                           |COMANDO DA AERONAUTICA                   |                                          |
# |2018-12-10    |2023-12-10     |2018-12-11        |2021-03-30       |                                                                                                                             |118058445|Pregão                      |001302018|Sem informação|Objeto: CONTRATAÇÃO DE SERVIÇOS DE CESSÃO, GERENCIAMENTO E ATIVAÇÃO DE MEIOS SATELITAIS NA BANDA C, EM TRANSPONDERS ADJACENTES TOTALIZANDO 108 MHZ, NECESSÁRIOS À COMUNICAÇÃO ENTRE AS ESTAÇÕES TERRENAS DO COMANDO DA AERONÁUTICA.                                                                                                                                                                                                                                                        |Não se aplica          |7.031746684E7   |2.69975979E7      |EDMILSON JOSE COSTA                 |000512018    |67600004316201810    |Objeto: Pregão Eletrônico -  Contratação de serviços de cessão, gerenciamento e ativação de meios satelitais na banda C, em transponders adjacentes totalizando 108 MHz, necessários à comunicação entre as Estações Terrenas do Comando da Aeronáutica, conforme condições, quantidades e exigências estabelecidas no Edital e seus anexos.                                                                                                                                                                |09.132.659/0001-76      |                       |27337448     |EMBRATEL TVSAT TELECOMUNICACOES SA                                         |EMBRATEL                                         |                                |EMBRATEL TVSAT TELECOMUNICACOES SA                                         |Entidades Empresariais Privadas|120195               |EXECUTIVO                    |CENTRO DE AQUISICOES ESPECIFICAS             |120195                      |EXECUTIVO                           |CENTRO DE AQUISIÇÕES ESPECIFICAS          |52000                            |Ministério da Defesa           |DEFESA                          |00394429000100                    |52111                                    |Comando da Aeronáutica            |CMDO AERONÁUTICA                   |20101                                   |Sem informação                        |                                       |                                         |52111                                           |COMANDO DA AERONAUTICA                   |                                          |
# |2018-04-02    |2023-04-02     |2018-04-02        |2018-07-06       |Fundamento Legal: LEI N° 8.666/93                                                                                            |118035917|Pregão                      |000812017|Sem informação|Objeto: CONTRATAÇÃO DE SERVIÇOS DE MANUTENÇÃO CORRETIVA, PREVENTIVA E ADEQUAÇÕES DE SISTEMAS ELETRÔNICOS DE SEGURANÇA                                                                                                                                                                                                                                                                                                                                                                      |Não se aplica          |134225.0        |134225.0          |WAGNER SOARES MATHEUS               |000512017    |67564010214201736    |Objeto: Pregão Eletrônico -  Contratação de empresa especializada para prestação de serviços de assistência técnica de manutenção preventiva, corretiva e adequação de instalações com o fornecimento de peças e componentes para parque de equipamentos de segurança eletrônica instalados na Guarnição da Aeronáutica dos Afonsos.                                                                                                                                                                        |05.925.793/0001-73      |                       |18142881     |ZOIT CONSULTORIA E SERVICOS DE TECNOLOGIA DA INFORMACAO LTDA               |                                                 |                                |ZOIT CONSULTORIA E SERVICOS DE TECNOLOGIA DA INFORMACAO LTDA               |Entidades Empresariais Privadas|120623               |EXECUTIVO                    |GRUPAMENTO DE APOIO DOS AFONSOS              |120623                      |EXECUTIVO                           |GRUPAMENTO DE APOIO DOS AFONSOS           |52000                            |Ministério da Defesa           |DEFESA                          |00394429000100                    |52111                                    |Comando da Aeronáutica            |CMDO AERONÁUTICA                   |20101                                   |Sem informação                        |                                       |                                         |52111                                           |COMANDO DA AERONAUTICA                   |                                          |
# |2018-05-18    |2022-01-01     |2018-05-18        |2018-12-21       |Fundamento Legal: LEI 8666/93                                                                                                |118039309|Inexigibilidade de Licitação|000082018|Sem informação|Objeto: PRESTAÇÃO DE SERVIÇOS DE ASSISTENCIA MEDICA HOSPITALAR.                                                                                                                                                                                                                                                                                                                                                                                                                            |Não se aplica          |150000.0        |150000.0          |JULIO CESAR DA GAMA APOLINARIO      |000032018    |67530000984201849    |Objeto: Prestação de serviço médico-hospitalar complementar de saúde.                                                                                                                                                                                                                                                                                                                                                                                                                                       |86.383.973/0001-72      |                       |19240971     |COOPERATIVA DE TRABALHO MEDICO E ATIVIDADES AFINS DE BELO HORIZONTE-BELCOOP|BELCOOP -BH                                      |                                |COOPERATIVA DE TRABALHO MEDICO E ATIVIDADES AFINS DE BELO HORIZONTE-BELCOOP|Entidades Empresariais Privadas|120636               |EXECUTIVO                    |GRUPAMENTO DE APOIO DE LAGOA SANTA           |120636                      |EXECUTIVO                           |GRUPAMENTO DE APOIO DE LAGOA SANTA        |52000                            |Ministério da Defesa           |DEFESA                          |00394429000100                    |52111                                    |Comando da Aeronáutica            |CMDO AERONÁUTICA                   |20101                                   |Sem informação                        |                                       |                                         |52111                                           |COMANDO DA AERONAUTICA                   |                                          |
# |2018-05-28    |2018-11-19     |2018-05-28        |2018-05-30       |Fundamento Legal: Lei n¿ 8.666/93, Decreto n¿ 2.271/97.                                                                      |118039565|Inexigibilidade de Licitação|102018   |Sem informação|Objeto: Serviços técnicos especializados de treinamento e aquisição de licenças do software FME, incluindo o fornecimento de 2 (duas) licenças fixas desktop da ferramenta FME, documentação técnica da instalação/configuração e manual degarantia técnica.                                                                                                                                                                                                                               |Publicado              |51538.32        |51538.32          |EDMILSON JOSE COSTA                 |000122018    |67600019013201711    |Objeto: Aquisição de serviços técnicos especializados de treinamento e aquisição de licenças do software FME, conforme as especificações e as condições detalhadas no Projeto Básico nº 265.06.I00.PB.007.00.                                                                                                                                                                                                                                                                                               |09.277.679/0001-35      |                       |23843727     |INOVACAO TECNOLOGIA DA INFORMACAO GEOGRAFICA LTDA                          |INOVACAO TECNOLOGIA DA INFORMACAO GEOGRAFICA LTDA|                                |INOVACAO TECNOLOGIA DA INFORMACAO GEOGRAFICA LTDA                          |Entidades Empresariais Privadas|120646               |EXECUTIVO                    |GRUPAMENTO DE APOIO AS UNIDADES DO SISTEMA DE|120646                      |EXECUTIVO                           |GRUPAMENTO DE APOIO ÀS UND DO SIST DO CEA |52000                            |Ministério da Defesa           |DEFESA                          |00394429000100                    |52111                                    |Comando da Aeronáutica            |CMDO AERONÁUTICA                   |20101                                   |Sem informação                        |                                       |                                         |52111                                           |COMANDO DA AERONAUTICA                   |                                          |
# |2018-06-01    |2048-06-01     |2018-06-01        |2021-03-24       |                                                                                                                             |118039949|Dispensa de Licitação       |000052018|Sem informação|Objeto: SERVIÇO PÚBLICO - ENERGISA                                                                                                                                                                                                                                                                                                                                                                                                                                                         |Não se aplica          |14000.0         |14000.0           |PAULO EDUARDO ALBUQUERQUE DE MAGELLA|000052015    |43/CINDACTA3/2015    |Objeto: Fornecimento de energia DTCEA-AR                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |09.095.183/0001-40      |                       |3420221      |ENERGISA PARAIBA - DISTRIBUIDORA DE ENERGIA S.A                            |ENERGISA                                         |                                |ENERGISA PARAIBA - DISTRIBUIDORA DE ENERGIA S.A                            |Entidades Empresariais Privadas|120632               |EXECUTIVO                    |GRUPAMENTO DE APOIO DE RECIFE                |120632                      |EXECUTIVO                           |GRUPAMENTO DE APOIO DE RECIFE             |52000                            |Ministério da Defesa           |DEFESA                          |00394429000100                    |52111                                    |Comando da Aeronáutica            |CMDO AERONÁUTICA                   |20101                                   |Sem informação                        |                                       |                                         |52111                                           |COMANDO DA AERONAUTICA                   |                                          |
# |2018-06-11    |2019-06-10     |2018-06-11        |2018-06-20       |Fundamento Legal: Lei nº 8.666, de 21 de junho de 1993, na Lei nº 10.520, de 17 de julho de 2002, na Lei Complementar nº 123.|118040333|Inexigibilidade de Licitação|52018    |Sem informação|Objeto: Prestação de serviços especializados em Radiocirurgia (RTC) - nível 1, lesão única e/ou um isocentro - por tratamento, Radiocirurgia (RTC) - nível 2, duas lesões e/ou dois a quatro isocentros - por tratamento, Radiocirurgia (RTC) - nível 3, três lesões e/ou de mais de quatro isocentros - por tratamento, Radioterapia com Modulação da Intensidade do Feixe (IMRT) - portratamento, Radioterapia Conformada Tridimensional (RCT-3D) com Acelerador Linear - por tratamento.|Publicado              |164417.08       |100000.0          |MARCO HAROLDO AKIO ODAM             |000092018    |67619006973201711    |Objeto: Credenciamento de serviços Médicos-Hospitalares - ONCOVILLE ATENDIMENTO ONCOLÓGICO INTEGRAL LTDA.                                                                                                                                                                                                                                                                                                                                                                                                   |04.707.180/0001-05      |                       |14142724     |ONCOVILLE ATENDIMENTO ONCOLOGICO INTEGRAL LTDA                             |                                                 |                                |ONCOVILLE ATENDIMENTO ONCOLOGICO INTEGRAL LTDA                             |Entidades Empresariais Privadas|120644               |EXECUTIVO                    |GRUPAMENTO DE APOIO DE CURITIBA              |120644                      |EXECUTIVO                           |GRUPAMENTO DE APOIO DE CURITIBA           |52000                            |Ministério da Defesa           |DEFESA                          |00394429000100                    |52111                                    |Comando da Aeronáutica            |CMDO AERONÁUTICA                   |20101                                   |Sem informação                        |                                       |                                         |52111                                           |COMANDO DA AERONAUTICA                   |                                          |
# +--------------+---------------+------------------+-----------------+-----------------------------------------------------------------------------------------------------------------------------+---------+----------------------------+---------+--------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------+----------------+------------------+------------------------------------+-------------+---------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------+-----------------------+-------------+---------------------------------------------------------------------------+-------------------------------------------------+--------------------------------+---------------------------------------------------------------------------+-------------------------------+---------------------+-----------------------------+---------------------------------------------+----------------------------+------------------------------------+------------------------------------------+---------------------------------+-------------------------------+--------------------------------+----------------------------------+-----------------------------------------+----------------------------------+-----------------------------------+----------------------------------------+--------------------------------------+---------------------------------------+-----------------------------------------+------------------------------------------------+-----------------------------------------+------------------------------------------+
# only showing top 20 rows
